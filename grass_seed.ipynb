# %%
cost = float(input())
numLawns = int(input())
total_cost = 0.0
for i in range(numLawns):
  length,width = map(float,input().split())
  area = length*width
  total_cost += cost*area
print(total_cost)
# Out:
# 0.75
# 2
# 2 3.333
# 3.41 4.567
# 16.6796025

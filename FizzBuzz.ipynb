# %%
x,y,N = map(int,input().split())
for i in range(1,N+1):
  if i%x == 0 and i%y ==0:
    print("FizzBuzz")
  elif i%x ==0:
    print("Fizz")
  elif i%y ==0:
    print("Buzz")
  else:
    print(i)
# Out:
# 2 4 7
# 1
# Fizz
# 3
# FizzBuzz
# 5
# Fizz
# 7

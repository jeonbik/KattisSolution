# %%
num = int(input())
for i in range(num):
  a,b,c = map(int,input().split())
  if a+b == c:
    print("Possible")
  elif b+a == c:
    print("Possible")
  elif a-b==c:
    print("Possible")
  elif a*b == c:
    print("Possible")
  elif b*a == c:
    print("Possible")
  elif a/b ==c:
    print("Possible")
  elif b/a == c:
    print("Possible")
  elif b-a==c:
    print("Possible")
  else:
    print("Impossible")
# Out:
# 6
# 1 2 3
# Possible
# 2 24 12
# Possible
# 5 3 1
# Impossible
# 9 16 7
# Possible
# 7 2 14
# Possible
# 12 4 2
# Impossible

# %%
6
1 2 3
2 24 12
5 3 1
9 16 7
7 2 14
12 4 2

# %%
num = int(input())
for i in range(num):
  a,b,c = map(int,input().split())
  if (b - c) == a:
    print("does not matter")
  elif (b-c) > a:
    print("advertise")
  else:
    print("do not advertise")
# Out:
# 1
# -100 -70 40
# do not advertise

# %%
0 100 70
100 130 30
-100 -70 40

# %%
advertise
does not matter
do not advertise

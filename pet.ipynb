# %%
max_pts = 0
winner = 0
for i in range(5):
  a,b,c,d = map(int,input().split())
  sum_out = a+b+c+d
  if sum_out > max_pts:
    winner = i
    max_pts = sum_out
print(winner+1,max_pts)
# Out:
# 5 4 4 5
# 5 4 4 4
# 5 5 4 4
# 5 5 5 4
# 4 4 4 5

# %%
winner
# Out:
# 3

# %%
5 4 4 5
5 4 4 4
5 5 4 4
5 5 5 4
4 4 4 5

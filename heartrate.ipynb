# %%
num = int(input())
for i in range(num):
  b,p = map(float,input().split())
  BPM = 60 * b/p
  t = 60/p
  print(BPM-t,BPM,BPM+t)
# Out:
# 1
# 6 5
# 60.0 72.0 84.0

# %%
a,b = map(int,input().split())
k = str(a)[::-1]
l = str(b)[::-1]
print(max(int(k),int(l)))
# Out:
# 734 893
# 437

# %%
2k
# Out:
# '354'

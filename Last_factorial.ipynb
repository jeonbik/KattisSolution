# %%
num = int(input())
for i in range(num):
  temp = int(input())
  factorial = 1
  for i in range(1,temp+1):
    factorial = factorial * i
  digit = str(factorial)
  print(digit[-1])

# %%
3
1
2
3 

1
2
6

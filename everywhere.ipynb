# %%
num = int(input())
for i in range(num):
  array_ = []
  num_cities = int(input())
  for j in range(num_cities):
    city = input()
    if city not in array_:
      array_.append(city)
  print(len(array_))
